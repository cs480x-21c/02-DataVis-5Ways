# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars = pd.read_csv("cars-sample.csv")

# %%
cars = cars.sort_values('Manufacturer', ascending=True)

# %%
cars
# Out:
#     Unnamed: 0                  Car Manufacturer   MPG  Cylinders  \
# 6           30                 2002          bmw  26.0          4
# 58         250                 320i          bmw  21.5          4
# 0            5               torino         ford  17.0          8
# 37         167                  ltd         ford  14.0          8
# 38         174           mustang ii         ford  13.0          8
# ..         ...                  ...          ...   ...        ...
# 65         278   celica gt liftback       toyota  21.1          4
# 71         318       corolla tercel       toyota  38.1          4
# 8           38               corona       toyota  25.0          4
# 20          90  corona mark ii (sw)       toyota  23.0          4
# 48         213              corolla       toyota  28.0          4
#
#     Displacement  Horsepower  Weight  Acceleration  Model.Year    Origin
# 6            121       113.0    2234          12.5          70  European
# ...

# %%
fig, ax = plt.subplots(figsize=(8.5,6), dpi=120)
sns.set(style='darkgrid')
sns.scatterplot(data=cars, x='Weight', y='MPG', hue='Manufacturer', size='Weight', alpha=0.5, palette='husl',
               sizes=(20, 200))
ax.set_yticks([10,20,30,40])
ax.set_xticks([2000,3000,4000,5000])
plt.legend(bbox_to_anchor=(1.02, .75), loc=2, borderaxespad=0., labelspacing=.7,)
plt.tight_layout()
plt.savefig("way-4-matplotlib-seaborn.png")
plt.show()
